# %%
import cv2

import numpy as np
import pandas as pd

from collections import Counter
from image_utils import get_features

# %%
img = cv2.imread("/Users/ateendraramesh/Downloads/face.png", 0)
img = cv2.resize(img, (24, 24))

# %%
img=np.ones_like(img)

# %%
f = get_features(img)

# %%
features, context = f

# %%
len(features)
# Out:
# 162336

# %%
Counter(features)
# Out:
# Counter({0.0: 107136,
#          -1.0: 1056,
#          -2.0: 1924,
#          -3.0: 1736,
#          -4.0: 2422,
#          -5.0: 1360,
#          -6.0: 2744,
#          -7.0: 984,
#          -8.0: 2192,
#          -9.0: 1408,
#          -10.0: 1880,
#          -11.0: 616,
#          -12.0: 2860,
#          -13.0: 528,
#          -14.0: 1352,
#          -15.0: 1520,
#          -16.0: 1634,
#          -17.0: 352,
#          -18.0: 1832,
#          -19.0: 264,
#          -20.0: 1730,
#          -21.0: 928,
#          -22.0: 664,
#          -23.0: 88,
#          -24.0: 1914,
#          -26.0: 456,
#          -28.0: 1054,
#          -30.0: 1520,
#          -32.0: 826,
#          -34.0: 304,
#          -36.0: 1364,
#          -38.0: 228,
#          -40.0: 960,
#          -42.0: 908,
#          -44.0: 478,
#          -46.0: 76,
#          -48.0: 940,
#          -27.0: 512,
#          -33.0: 448,
#          -39.0: 384,
#          -45.0: 640,
#          -51.0: 256,
#          -54.0: 448,
# ...

# %%
df = pd.read_csv("/Users/ateendraramesh/Downloads/temp.csv")

# %%
Counter([x for x in df["Values"]])
# Out:
# Counter({0.0: 7748,
#          -26.0: 102,
#          -25.0: 92,
#          2.0: 119,
#          -22.0: 110,
#          -53.0: 62,
#          -100.0: 45,
#          -129.0: 53,
#          -166.0: 23,
#          -254.0: 26,
#          -59.0: 43,
#          -33.0: 84,
#          -83.0: 66,
#          -183.0: 26,
#          -316.0: 30,
#          -430.0: 24,
#          -534.0: 16,
#          -725.0: 9,
#          -70.0: 62,
#          -30.0: 116,
#          -75.0: 58,
#          -121.0: 56,
#          -238.0: 28,
#          -376.0: 16,
#          -455.0: 17,
#          -544.0: 12,
#          -850.0: 7,
#          -230.0: 25,
#          -320.0: 18,
#          -407.0: 24,
#          -339.0: 23,
#          -251.0: 21,
#          -179.0: 33,
#          -181.0: 30,
#          -32.0: 88,
#          -261.0: 25,
#          -481.0: 21,
#          -874.0: 18,
#          -1085.0: 5,
#          -933.0: 8,
#          -759.0: 6,
#          -466.0: 20,
#          -87.0: 57,
#          -180.0: 29,
# ...

# %%
df
# Out:
#        Unnamed: 0  Values
# 0               0     0.0
# 1               1     0.0
# 2               2     0.0
# 3               3     0.0
# 4               4     0.0
# 5               5     0.0
# 6               6     0.0
# 7               7     0.0
# 8               8     0.0
# 9               9   -26.0
# 10             10   -25.0
# 11             11     2.0
# 12             12   -22.0
# 13             13   -53.0
# 14             14  -100.0
# 15             15  -129.0
# 16             16  -166.0
# 17             17  -254.0
# 18             18   -26.0
# 19             19   -25.0
# 20             20     2.0
# 21             21   -22.0
# 22             22   -53.0
# 23             23  -100.0
# 24             24  -129.0
# 25             25  -166.0
# 26             26  -254.0
# 27             27   -59.0
# 28             28   -33.0
# 29             29   -26.0
# ...           ...     ...
# 63930       63930  -778.0
# 63931       63931  -670.0
# 63932       63932     0.0
# ...
